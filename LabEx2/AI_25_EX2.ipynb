# %% [markdown]
# # Τεχνητή Νοημοσύνη: Εργαστηριακή Άσκηση 2
# ---
#
# Ο στόχος της εργασίας είναι η κατασκευή ενός συστήματος προτάσεων (Recommendation System) για ταινίες. Οι προτάσεις αυτές θα πηγάζουν τόσο από τα χαρακτηριστικά της ταινίας όσο και από ορισμένες αξιολογήσεις του κάθε χρήστη.
#
# Στα δεδομένα της άσκησης περιλαμβάνονται ένα αρχείο με το όνομα movies_metadata.csv το όποιο περιέχει τα χαρακτηριστικά κάθε ταινίας όπως θέμα, σκηνοθέτης ηθοποιοί, λέξεις κλειδιά κ.α. από το imdb καθώς και τα αρχεία ratings.csv τα όποια περιέχουν πραγματικές αξιολογήσεις χρηστών, χωρισμένες σε train και σε test.

# %% [markdown]
# # Εκφώνηση
# Στην παρούσα εργασία σας ζητείται να μελετήσετε και να υλοποιήσετε τα παρακάτω:<br>
#
# ### Μέρος 1
# Στο μέρος 1 και 2 θα εργαστείτε μόνο με το αρχείο movies_metadata.csv, ενώ στο μέρος τρία θα δουλέψετε και με τα αρχεία των αξιολογήσεων.
# #### Ερώτημα 1α
#
# Αρχικά θα πρέπει, αφού μελετήσετε τη δομή και τα χαρακτηριστικά του movies_metadata.csv, να κατασκευάσετε μια βάση γνώσης για την Prolog η όποια ουσιαστικά θα αποτελεί τον κόσμο με τον όποιο θα εργαστείτε στην συνέχεια. Τα κατηγορήματα που θα δημιουργηθούν θα σας βοηθήσουν και στην κατασκευή του recommender και θα είναι της μορφής:
#
# ```
# director(Movie, Director).
# genre(Movie, Genre).
# ```
# #### Ερώτημα 1β
#
# Αφού δημιουργήσετε τον κόσμο του προβλήματος, στη συνέχεια καλείστε να δημιουργήσετε, σε Prolog, απλούς κανόνες οι οποίοι θα βρίσκουν όλες τις ταινίες με:
# 1.	Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
# 2.	Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
# 3.	Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
# 4.	Κοινός σκηνοθέτης
# 5.	Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
# 6.	Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
# 7.	Ίδιους τους βασικούς ηθοποιούς (και τους 3)
# 8.	Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
# 9.	Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
# 10.	Ίδια γλώσσα
# 11.	Είναι έγχρωμες ή ασπρόμαυρες
# 12. Κοινό studio παραγωγής
# 13. Κοινή χώρα παραγωγής
# 14. Ίδια δεκαετία
#
# Αξίζει να σημειωθεί ότι στα παραπάνω μπορείτε να προσθέσετε περισσότερα ερωτήματα ή να αλλάξετε την κλιμακωσιμότητα των queries (πέρα από το ίδιο, αρκετά ίδιο, σχετικά ίδιο) που θα κατασκευάσετε(π.χ. μια κλίμακα από 1 στα 5 όπου αυτό είναι δυνατόν), μιας και αυτά στην συνέχεια θα χρησιμοποιηθούν για την λειτουργία του recommender. Έτσι μπορείτε να προσθέσετε queries με τα όποια μπορεί να παράγονται καλύτερες συστάσεις  (το αρχείο movie_metadata.csv περιέχει πολλές πληροφορίες ακόμα για κάθε ταινία όπως έτος κυκλοφορίας, βαθμολογία στο imdb, facebοok_likes κ.α.). Το συγκεκριμένο μέρος εργασίας είναι προπαρασκευαστικό οπότε όσο καλύτερα και πλουσιότερα τα ερωτήματα που θα φτιάξετε σε αυτό το μέρος τόσο καλύτερη θα είναι η απόδοσή των συστημάτων συστάσεων των επόμενων ερωτημάτων.
#
# Περισσότερες πληροφορίες για το dataset μπορείτε να διαβάσετε σε αυτό το [Link](https://www.kaggle.com/georgefila/movies-metadata).
# ### Μέρος 2: Recommendation System
# Στο σημείο αυτό καλείστε με βάση αυτά που κάνατε στο μέρος 1 να κατασκευάσετε queries τα όποια θα σας επιστρέφουν παρόμοιες (σε χαρακτηριστικά) ταινίες. Τα ερωτήματα αυτά θα είναι κλιμακούμενα, δηλαδή θα υπάρχουν ερωτήματα που επιστρέφουν αρκετά κοινές ταινίες αλλά και που επιστρέφουν λιγότερο και λιγότερο κοινές (σε μια κλίμακα π.χ. από 1 σε 5). Για παράδειγμα:
#
# ```
# find_simmilar_movies_5("Pirates Of The Caribbean", M).
# M = "Pirates Of The Caribbean: On Stranger Tides"
# M = "The Chronicles Of Narnia"
# M = "Prince Of Persia: The Sands Of Time"
# ...
# ```
# Για παράδειγμα, το παραπάνω ερώτημα θα επιστρέφει αρκετά κοινές σε περιεχόμενο ταινίες με την ταινια "Pirates Of The Caribbean". Θα υπάρχουν και αντίστοιχα ερωτήματα που θα βρίσκουν λιγότερο όμοιες ταινίες. Ο δείκτης ομοιότητας των ταινιών είναι αυθαίρετος και μπορείτε να τον ορίσετε εσείς όπως θέλετε, αρκεί να υπάρχει κάποια λογική σύνδεση με τα δεδομένα που περιέχονται στο αρχείο movies_metadata.csv.
#
# Συνεπώς η συνάρτηση που θα κάνει τις προτάσεις (recommendation) με είσοδο μια ταινία πρέπει να επιστρέφει-εκτυπώνει μια λίστα με τις προτεινόμενες ταινίες κατά φθίνουσα σειρά ομοιότητας.
#
#
# ###3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις - Αξιολογήσεις του χρήστη
#
#
# Σε αυτό το σημείο θα εργαστείτε με τα αρχεία ratings τα όποια περιέχουν αξιολογήσεις (από 1 μέχρι 5) για τις παραπάνω ταινίες. Το προηγούμενο σύστημα συστάσεων προτείνει στον χρήστη ταινίες αποκλειστικά με βάση την ομοιότητά τους. Σε αυτό το σημείο θα γίνει μια αναβάθμιση του συστήματος έτσι ώστε να παράγονται καλύτερες  συστάσεις οι όποιες θα λαμβάνουν υπόψιν και τις προτιμήσεις του χρήστη, οι όποιες θα εξάγονται από τις αξιολογήσεις που έχει κάνει μέχρι στιγμής.
#
# Η εκπαίδευση του recommender θα γίνεται ως εξής:
#
# Για κάθε ταινία θα υπάρχει ένα score το όποιο αρχικά θε είναι ίσο με 0 και θα διαμορφώνεται από τις αξιολογήσεις κάθε user. Έτσι για έναν χρήστη με βάση τις αξιολογήσεις που υπάρχουν στο αρχείο train_ratings θα πρέπει:
#
# 1.	Για κάθε ταινία που έχει βαθμολογήσει να βρίσκονται οι κοινές ταινίες ανά κλίμακα και στο μέχρι τώρα σκορ κάθε παρόμοιας ταινίας θα προστίθεται ένα βάρος το όποιο θα μπορούσε να είναι το ποσοστό ομοιότητας της ταινίας (δηλαδή ένα βάρος για κάθε κλίμακα, αν δύο ταινίες μοιάζουν ενισχύουμε το βάρος που προσθέτουμε από το να μοιάζουν λιγότερο) επί τον βαθμό που έχει βάλει ο χρήστης για την αρχική ταινία (διαφορετικό είναι ο χρήστης να έχει βάλει 5/5 ή 1/5 σε μια ταινία από 3/5).
#
# 2. Στη συνέχεια, ανάλογα με το σκορ που έχει σχηματιστεί για κάθε ταινία, θα επιλέγεται αν αυτή θα μπορούσε να είναι προτεινόμενη για τον χρήστη ή όχι και θα μετράμε το πόσο καλά τα πήγε το σύστήμά μας με βάση ορισμένες μετρικές.
#
# Η λογική πίσω από την παραπάνω διαδικασία είναι ότι παρόμοιες ταινίες θα έχουν ανάλογο βαθμό. Για παράδειγμα αν ένας χρήστης έχει αξιολογήσει αρκετές  ταινίες οι όποιες είναι sci-fiction με 5/5 τότε μια ταίνια sci-fiction την όποια δεν έχει δεί λογικά θα του αρέσει και θα έπρεπε να την προτείνουμε.
#
# Μετά την εκπαίδευση του συστήματος σας καλείστε να δοκιμάσετε τον recommender που κατασκευάσατε στην πράξη. Για τον σκοπό αυτό θα φορτώσετε το αρχείο test_ratings.csv όπου περιέχονται οι αξιολογήσεις του ίδιου χρήστη για άλλες ταινίες. Το σύστημά σας πρέπει να προβλέπει αν μια ταινία θα πρέπει να προταθεί στον χρήστη. Μια ταίνια θεωρούμε οτι προτείνεται στον  χρήστη, αν έχει βαθμό μεγαλύτερο του 3 στο test_ratings. Συνεπώς για την επίβλεψη του συστήματός σας θα πρέπει για κάθε μια από τις ταινίες του αρχείου test_ratings.csv να προβλέψετε εάν θα αρέσει στο χρήστη ή όχι ώστε να την προτείνετε.
#
# ΠΡΟΣΟΧΗ! Η "βαθμολογία" που θα υπολογίσετε για κάθε ταινία κατά το training δεν είναι απαραίτητα πρόβλεψη της βαθμολογίας που θα έβαζε ο χρήστης.
#
# Στην συνέχεια, σε συνδιασμό με τις πραγματικές απαντήσεις του χρήστη θα αξιολογήσετε το σύστημά σας χρησιμοποιόντας τις μετρικές: precision, recall, f1 οι οποίες είναι οι πλέον γνωστές μετρικές και ευρέως χρησιμοποιούμενες τεχνικές για την επίβλεψη-μέτρηση απόδοσης ανάλογων συστημάτων.
#
# 1. Precision: Δείχνει πόσο ακριβές είναι το σύστημα. Υπολογίζει πόσα από τα στιγμιότυπα τα όποια προβλέψαμε ότι ανήκουν σε μια κλάση όντως ανήκουν σε αυτή. Η μετρική αυτή μας δίνει μια εικόνα σχετικά με τον αριθμό των ταινίων που προβλέψαμε ως προτεινόμενες ενώ δεν θα έπρεπε.
#
# 2. Recall: Υπολογίζει πόσα από τα στιγμιότυπα που ανήκουν σε μια κλάση (π.χ. προτεινόμενες ταινίες) προβλέφθηκαν σωστά.
#
# 3. F1: Είναι ένας μέσος μεταξύ των παραπάνω δυο μετρικών, έτσι ώστε να διατηρείται μια ισορροπία μεταξύ τους. Υπολογίζεται από την παρακάτω σχέση:
#
# $$F_1=2\frac{Precision\times{Recall}}{Precision+Recall}$$
#
# Οι παραπάνω συναρτήσεις παρέχονται από την βιβλιοθήκη scikit-learn.
#
# Τέλος για την καλύτερη επίβλεψη του συστήματος σας μπορείτε να εκπαιδεύσετε  τον recommender σας με ένα υποσύνολο ταινίων από ελάχιστες, λίγες μέχρι και πολλές (π.χ. 3, 5, 10, 50, ...) για να μελετήσετε κατά πόσο σας βοηθούν οι επιπλέον αξιολογήσεις κάθε φορά (δηλαδή κατά πόσο βελτιώνονται οι παραπάνω μετρικές στο test set).
#
# Έτσι π.χ. μπορείτε να εντοπίσετε περιπτώσεις όπως για παράδειγμα ότι με έναν recommender μπορεί να μην επιτυγχάνετε πολύ υψηλό σκορ όσο με άλλους, αλλά το βέλτιστο σκόρ σας επιτυγχάνεται πολύ γρηγόρα π.χ. με μόνο 10 ταινίες αντί 100. Έτσι για παράδειγμα αν ο αλγόριθμος τα πηγαίνει πολύ καλά για τρεις ταινίες και στη συνέχεια το σκορ βελτιώνεται ελάχιστα τότε αυτός ενδείκνυται για ένα σύστημα συστάσεων για νέους χρήστες όπου δεδομένου λίγων ταινιών ο αλγόριθμος είναι σε θέση να το να προτείνει καλές συστάσεις. Ενώ αν η καλύτερη απόδοση του αλγορίθμου σας είναι βέλτιστη με περισσότερες ταινίες π.χ. 50 τότε αυτός ο αλγόριθμος συστάσεων ενδείκνυται για παλιούς χρήστες με πολλές αξιολόγησεις.

# %% [markdown]
# ---
# ## Κατασκευή Περιβάλλοντος Εργασίας
# ---
# ### Διάβασμα Αρχείων στο Colab (Μόνο για το Colab)
# Αν η υλοποίηση γίνει στο google colab τότε μπορεί να χρησιμοποιηθεί το google drive ως file system. Για να γίνει Mount το google drive τρέχουμε τον παρακάτω κώδικα και κλικάρουμε στο link που θα μας εμφανιστεί.
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# import os
# os.listdir('/gdrive/My Drive')
# ```
# Έπειτα στην σελίδα που άνοιξε επιλέγουμε το mail μας και στο επόμενο παράθυρο που θα μας ανοίξει πατάμε Να επιτρέπεται. Στην συνέχεια αντιγράφουμε τον κωδικό που θα μας βγάλει και τον κάνουμε paste στο Input που έχει ανοίξει στο colab. Έτσι πλέον αν έχουμε ανεβάσει ένα αρχείο στο google drive μπορούμε να το βρούμε στην θέση:
#
# ```
# movies_filename = '/gdrive/My Drive/' + movies_metadata.csv
# ```
# Μπορούμε πλέον κανονικά να δουλέψουμε φτιάχνοντας φακέλους ή αρχεία και γενικότερα κάνοντας οτιδήποτε θα κάναμε αν ήμασταν τοπικά.
#
# ### Prolog μέσω Python
#
# Το πακέτο που θα χρησιμοποιηθεί για την επικοινωνία Python και Prolog είναι το pyswip (https://pypi.org/project/pyswip/). Για να δουλέψει το Pyswip  χρειάζεται να υπάρχει το Swi-Prolog το όποιο αν δουλεύουμε τοπικά πρέπει να το εγκαταστήσουμε, ακολουθώντας αντίστοιχες οδηγίες στην σελίδα του εργαλείου. Για να γίνει του Swi-Prolog η εγκατάσταση στο Google Colab πρέπει να τρέξουμε τον παρακάτω κώδικα:
#
# ```
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# ```
# Σε κάποιο σημείο της εκτέλεσης εμφανίζεται ένα μήνυμα ότι πρέπει να πατήσουμε enter σε ένα input για να συνεχίσει η διαδικασία. Έπειτα από αυτό η εκτέλεση θα συνεχίσει χωρίς κάποιο πρόβλημα.
#
# Τέλος πρέπει να εγκαταστήσουμε το pyswip (**όπου και να δουλεύουμε**) όπως παρακάτω:
#
# ```
# !pip isntall pyswip
# ```

# %% [markdown]
# ---
# #Κώδικας για κατασκευή περιβάλλοντος εργασίας
#
# ##Μόνο για Google Colab
#
# Κώδικας για να γίνει Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
path="/content/drive/MyDrive/UNI/AI/2/to_upload/" # με ευκόλο τρόπο μπορείτε να αλλάξετε το path που είναι αποθηκευμένα τα αρχεία σας
#os.listdir('/gdrive/My Drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%capture
#install swi-prolog
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog
# !sudo apt-get update
# !sudo apt-get install swi-prolog
#install pyswip
# !pip install pyswip

# %% [markdown]
# # **Μέρος 1: Μελέτη των Metadata, Δημιουργία κόσμου και των βασικών queries.**

# %%
import pandas as pd
from pyswip import Prolog

# %%
# Η βιβλιοθήκη pandas είναι χρήσιμη για την εργασία με τέτοια δεδομένα
import pandas as pd
path = '/content/drive/MyDrive/UNI/AI/2/to_upload/'
# Διάβασμα του αρχείου 'movie_metadata.csv'
data = pd.read_csv(path + "movies_metadata.csv")
#Στο csv υπαρχούν κελία με nan τιμές
#Στις θέσεις αυτές βάζουμε 'UNK' πράγμα που  κάνουμε με την παρακάτω συνάρτηση
data.fillna("UNK", inplace=True)
# Preview the first 5 lines of the loaded data
data.head()
# Out:
# <ipython-input-4-35053e8dc741>:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'UNK' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.fillna("UNK", inplace=True)
#    Unnamed: 0     budget                                    genres  \
# 0           0  237000000  Action|Adventure|Fantasy|Science Fiction
# 1           1  300000000                  Adventure|Fantasy|Action
# 2           2  245000000                    Action|Adventure|Crime
# 3           3  250000000               Action|Crime|Drama|Thriller
# 4           4  260000000          Action|Adventure|Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                        plot_keywords  language  \
# 0  culture clash|future|space war|space colony|so...   English
# 1  ocean|drug abuse|exotic island|east india trad...   English
# 2  spy|based on novel|secret agent|sequel|mi6|bri...  Français
# 3  dc comics|crime fighter|terrorist|secret ident...   English
# 4  based on novel|mars|medallion|space travel|pri...   English
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  ...  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...
# 2  A cryptic message from Bond’s past sends him o...  107.376788  ...
# 3  Following the death of District Attorney Harve...  112.312950  ...
# 4  John Carter is a war-weary, former military ca...   43.926995  ...
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                 movie_title vote_average  num_voted_users  \
# 0                                    Avatar          7.2            11800
# 1  Pirates of the Caribbean: At World's End          6.9             4500
# 2                                   Spectre          6.3             4466
# 3                     The Dark Knight Rises          7.6             9106
# 4                               John Carter          6.1             2124
#
#   title_year                   country      director_name     actor_1_name  \
# 0     2009.0  United States of America      James Cameron      Zoe Saldana
# 1     2007.0  United States of America     Gore Verbinski    Orlando Bloom
# 2     2015.0            United Kingdom         Sam Mendes  Christoph Waltz
# 3     2012.0  United States of America  Christopher Nolan    Michael Caine
# 4     2012.0  United States of America     Andrew Stanton     Lynn Collins
#
#        actor_2_name       actor_3_name
# 0  Sigourney Weaver       Stephen Lang
# 1   Keira Knightley  Stellan Skarsgård
# 2       Léa Seydoux      Ralph Fiennes
# 3       Gary Oldman      Anne Hathaway
# 4   Samantha Morton       Willem Dafoe
#
# [5 rows x 27 columns]

# %%
def clean_text(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  return text

# %%
#create World
#Ορίζουμε τον κόσμο μας
prolog = Prolog()

import ast

#Για κάθε row του πίνακα φτιάχνουμε τα κατηγορήματα που θέλουμε να αποθηκέυσουμε
#αρχικά σε μια λίστα με το όνομα literals
literals = []
movie_score = {}
for row in data.itertuples(index=True, name='Pandas'):
  movie_title = clean_text(getattr(row, 'movie_title'))
  literals.append("movie('"+ movie_title +"')")

  for genre in getattr(row, 'genres').split("|"):
    literals.append("genre('"+ movie_title +"','"+ genre +"')")

  director = clean_text(getattr(row, 'director_name'))
  literals.append("director('"+ movie_title +"','"+ director +"')")

  has_black_and_white = False;
  for plot_keyword in getattr(row, 'plot_keywords').split("|"):
    keyword = clean_text(plot_keyword)
    literals.append("plot_keyword('"+ movie_title +"','"+ keyword +"')")
    if keyword == 'black and white':
      has_black_and_white = True;

  if has_black_and_white:
    literals.append("black_and_white('"+ movie_title +"')")
  else:
    literals.append("color('"+ movie_title +"')")

  actor1 = clean_text(getattr(row, 'actor_1_name'))
  actor2 = clean_text(getattr(row, 'actor_2_name'))
  actor3 = clean_text(getattr(row, 'actor_3_name'))
  literals.append("actor('"+ movie_title +"','"+ actor1 + "')")
  literals.append("actor('"+ movie_title +"','"+ actor2 + "')")
  literals.append("actor('"+ movie_title +"','"+ actor3 + "')")

  language = clean_text(getattr(row, 'language'))
  literals.append("language('"+ movie_title +"','"+ language + "')")

  studios_str = getattr(row, 'production_companies')
  studios = ast.literal_eval(studios_str)
  for studio in studios:
    studio_name = clean_text(studio['name'])
    literals.append("studio('"+ movie_title +"','"+ studio_name +"')")


  countries_str = getattr(row, 'production_countries')
  countries = ast.literal_eval(countries_str)
  for country in countries:
    country_name = clean_text(country['name'])
    literals.append("country('"+ movie_title +"','"+ country_name +"')")

  release_date = getattr(row, 'release_date')
  release_year_str = release_date.split("-")[0]
  if release_year_str.isdigit():
    release_year = int(release_year_str)
    literals.append(f"release_year('{movie_title}', {release_year})")


#Η Prolog θέλει τα κατηγορήματά της με την σειρά
literals.sort()
for literal in literals:
  prolog.assertz(literal)
  #print (literal +'.')

#Επίσης μπορούμε να κάνουμε consult ένα έτοιμο αρχείο στον κόσμο όπως παρακάτω
#prolog.consult(path + "db=.pl")

# %%
prolog.assertz('(five_common_genre(Genre1,Genre2,Genre3,Genre4,Genre5,Y) :- findall(M, (genre(M,Genre1), genre(M,Genre2), genre(M,Genre3),genre(M,Genre4),genre(M,Genre5)), Y))')
prolog.assertz('three_common_genre(Genre1,Genre2,Genre3,Y) :- findall(M, (genre(M,Genre1), genre(M,Genre2), genre(M,Genre3)), Y)')
prolog.assertz('(one_common_genre(Genre1,Y) :- findall(M,genre(M,Genre1),Y))')

prolog.assertz('(directed_by(X,Y) :- findall(M,director(M,X),Y))')

prolog.assertz('(five_common_keyword(K1,K2,K3,K4,K5,Y) :- findall(M, (plot_keyword(M,K1), plot_keyword(M,K2), plot_keyword(M,K3), plot_keyword(M,K4), plot_keyword(M,K5)), Y))')
prolog.assertz('(three_common_keyword(K1,K2,K3,Y) :- findall(M, (plot_keyword(M,K1), plot_keyword(M,K2), plot_keyword(M,K3)), Y))')

# Using setof to remove duplicates
prolog.assertz('three_common_actor(Actor1,Actor2,Actor3,Y) :- setof(M, (actor(M,Actor1), actor(M,Actor2), actor(M,Actor3)), Y)')
prolog.assertz('two_common_actor(Actor1,Actor2,Y) :- setof(M, (actor(M,Actor1), actor(M,Actor2)), Y)')
prolog.assertz('one_common_actor(Actor1,Y) :- setof(M, (actor(M,Actor1)), Y)')

prolog.assertz('common_language(L,Y) :- setof(M, language(M,L), Y)')

prolog.assertz('black_and_white_movies(Y) :- findall(M, black_and_white(M), Y)')
prolog.assertz('color_movies(Y) :- setof(M, (movie(M), color(M)), Y)')

prolog.assertz('(common_production_studio(Studio1,Y) :- findall(M,studio(M,Studio1),Y))')

prolog.assertz('(common_production_country(Country1,Y) :- findall(M,country(M,Country1),Y))')

prolog.assertz('(same_decade(Movie1, Movie2) :- release_year(Movie1, Year1), release_year(Movie2, Year2), Decade1 is Year1 // 10, Decade2 is Year2 // 10, Decade1 =:= Decade2, Movie1 \= Movie2)')

print("5 Same Genres")
q = prolog.query("five_common_genre('Action','Comedy','Adventure','Fantasy','Drama',Y)")
for soln in q:
  s = soln['Y']
  print(s)
q.close()

print("3 Same Genres")
q = prolog.query("three_common_genre('Action','Fantasy','Adventure',Y)")
for soln in q:
  s = soln['Y']
  print(s)
q.close()

print("1 Same Genre")
q = prolog.query("one_common_genre('Action',Y)")
for soln in q:
  s = soln['Y']
  print(s)
q.close()

print("Directed by Christopher Nolan")
q = prolog.query("directed_by('Christopher Nolan',Y)")
for soln in q:
  s = soln['Y']
  print(s)
q.close()

print("5 Same Keywords")
q = prolog.query("five_common_keyword('dc comics', 'superhero','supervillain','dc extended universe', 'villain',Y)")
for soln in q:
  s = soln['Y']
  print(s)
q.close()

print("3 Same Keywords")
q = prolog.query("three_common_keyword('dc comics', 'superhero','alien',Y)")
for soln in q:
  s = soln['Y']
  print(s)
q.close()

print("3 Same Actors")
q = prolog.query("three_common_actor('Chris Evans','Chris Hemsworth','Mark Ruffalo',Y)")
for soln in q:
  s = soln['Y']
  print(s)
q.close()

print("2 Same Actors")
q = prolog.query("two_common_actor('Ben Affleck','Matt Damon',Y)")
for soln in q:
  s = soln['Y']
  print(s)
q.close()

print('Common Actor')
q = prolog.query("one_common_actor('Brad Pitt',Y)")
for soln in q:
  s = soln['Y']
  print(s)
q.close()

print("Common Language")
q = prolog.query("common_language('Français',Y)")
for soln in q:
  s = soln['Y']
  print(s)
q.close()

print("Black and White Movies")
q = prolog.query("black_and_white_movies(Y)")
for soln in q:
  s = soln['Y']
  print(s)
q.close()

print("Colored Movies")
q = prolog.query("color_movies(Y)")
for soln in q:
  s = soln['Y']
  print(s)
q.close()

print("Common Production Studio")
q = prolog.query("common_production_studio('Universal Pictures',Y)")
for soln in q:
  s = soln['Y']
  print(s)
q.close()

print("Common Production Country")
q = prolog.query("common_production_country('United Kingdom',Y)")
for soln in q:
  s = soln['Y']
  print(s)
q.close()

print("Movies released on the same decade as The Matrix")
q = prolog.query("same_decade('The Matrix',Y)")
for soln in q:
  s = soln['Y']
  print(s)
q.close()
# Out:
# 5 Same Genres
# ['The Sorcerers Apprentice']
# 3 Same Genres
# ['47 Ronin', 'Avatar', 'Batman v Superman: Dawn of Justice', 'Batman', 'Beastmaster 2: Through the Portal of Time', 'Big Trouble in Little China', 'Blade: Trinity', 'BloodRayne', 'Brave', 'Cirque du Freak: The Vampires Assistant', 'Clash of the Titans', 'Conan the Barbarian', 'Conan the Destroyer', 'Dragonball Evolution', 'Dungeons & Dragons: Wrath of the Dragon God', 'Eragon', 'Fantastic 4: Rise of the Silver Surfer', 'Final Fantasy: The Spirits Within', 'G-Force', 'Highlander', 'How to Train Your Dragon 2', 'In the Name of the King III', 'In the Name of the King: A Dungeon Siege Tale', 'Jimmy Neutron: Boy Genius', 'Jonah: A VeggieTales Movie', 'Jupiter Ascending', 'Krull', 'Lara Croft Tomb Raider: The Cradle of Life', 'Lara Croft: Tomb Raider', 'Last Action Hero', 'Maleficent', 'Man of Steel', 'Mighty Joe Young', 'Monkeybone', 'Mystery Men', 'Night at the Museum', 'Night at the Museum: Battle of the Smithsonian', 'Pirates of the Caribbean: At Worlds End', 'Pirates of the Caribbean: Dead Mans Chest', 'Pirates of the Caribbean: On Stranger Tides', 'Pirates of the Caribbean: The Curse of the Black Pearl', '
Day Out', 'Bad Boys II', 'Bad Boys', 'Bad Company', 'Bait', 'Ballistic: Ecks vs. Sever', 'Bandidas', 'Bandits', 'Bangkok Dangerous', 'Basic', 'Batman & Robin', 'Batman Begins', 'Batman Forever', 'Batman Returns', 'Batman v Superman: Dawn of Justice', 'Batman', 'Batman: The Dark Knight Returns, Part 2', 'Battle for the Planet of the Apes', 'Battle: Los Angeles', 'Battlefield Earth', 'Battleship', 'Beastmaster 2: Through the Portal of Time', 'Behind Enemy Lines', 'Beowulf', 'Beverly Hills Cop II', 'Beverly Hills Cop III', 'Beverly Hills Cop', 'Big Hero 6', 'Big Mommas: Like Father, Like Son', 'Big Trouble in Little China', 'Big Trouble', 'Black Hawk Down', 'Black November', 'Black Rain', 'Blackthorn', 'Blade II', 'Blade', 'Blade: Trinity', 'Blades of Glory', 'Blood Diamond', 'BloodRayne', 'Bloodsport', 'Bloody Sunday', 'Blue Streak', 'Body of Lies', 'Bodyguards and Assassins', 'Bon Cop Bad Cop', 'Born Of War', 'Bound by Honor', 'Brave', 'Braveheart', 'Breakdown', 'Brick Mansions', 'Broken Arrow', 'Bronson', 'Brooklyn Rules', 'Bullet to the Head', 'Bulletproof Monk', 'Bullets Over Broadway', 'Capricorn One', 'Captain America: Civil War', 'Captain America: The First Avenger', 'Captain America: The Winter Soldier', 'Captain Phillips', 'Caravans', 'Carriers', 'Casino Royale', 'Catch That Kid', 'Catch a Fire', 'Catwoman', 'Cellular', 'Central Intelligence', 'Centurion', 'Chain Reaction', 'Chain of Command', 'Changing Lanes', 'Chappie', 'Charlies Angels', 'Charlies Angels: Full Throttle', 'Checkmate', 'Chicago Overcoat', 'Chicago', 'Children of Men', 'Chill Factor', 'Cirque du Freak: The Vampires Assistant', 'Clash of the Titans', 'Class of 1984', 'Clear and Present Danger', 'Cliffhanger', 'Close Range', 'Cloverfield', 'Code Name: The Cleaner', 'Code of Honor', 'Collateral Damage', 'Colombiana', 'Commando', 'Compadres', 'Con Air', 'Conan the Barbarian', 'Conan the Destroyer', 'Confidence', 'Congo', 'Conquest of the Planet of the Apes', 'Conspiracy Theory', 'Contraband', 'Cop Land', 'Cop Out', 'Corky Romano', 'Cotton Comes to Harlem', 'Cradle 2 the Grave', 'Crank', 'Crank: High Voltage', 'Crazy Stone', 'Criminal', 'Crimson Tide', 'Crossover', 'Crossroads', 'Crouching Tiger, Hidden Dragon', 'Curse of the Golden Flower', 'Cutthroat Island', 'D-Tox', 'D.E.B.S.', 'DOA: Dead or Alive', 'Damnation Alley', 'Dance Flick', 'Dantes Peak', 'Dark Blue', 'Das Boot', 'Dawn of the Dead', 'Dawn of the Planet of the Apes', 'Daybreakers', 'Daylight', 'Dead Man Down', 'Deadpool', 'Death Race 2000', 'Death Race', 'Death Sentence', 'Deep  ...
# Directed by Christopher Nolan
# ['Batman Begins', 'Inception', 'Insomnia', 'Interstellar', 'Memento', 'The Dark Knight Rises', 'The Dark Knight', 'The Prestige']
# 5 Same Keywords
# ['Suicide Squad']
# 3 Same Keywords
# ['Green Lantern']
# 3 Same Actors
# ['Avengers: Age of Ultron', 'The Avengers']
# 2 Same Actors
# ['Good Will Hunting']
# Common Actor
# ['Burn After Reading', 'By the Sea', 'Fight Club', 'Megamind', 'Mr. & Mrs. Smith', 'Oceans Eleven', 'Oceans Thirteen', 'Oceans Twelve', 'Sleepers', 'Snatch', 'Spy Game', 'The Big Short', 'The Curious Case of Benjamin Button', 'The Devils Own']
# Common Language
# ['1911', '8 Women', 'A Monster in Paris', 'Aloft', 'Amour', 'Amélie', 'Asterix at the Olympic Games', 'Barbecue', 'Betty Fisher and Other Stories', 'Boomerang', 'Bottle Shock', 'Bright Star', 'Burnt', 'Camping Sauvage', 'Captain America: The First Avenger', 'Caramel', 'Cargo', 'Carlos', 'Cinco de Mayo: La Batalla', 'Coco Before Chanel', 'Desire', 'Dirty Pretty Things', 'District B13', 'Dragon Hunters', 'Elizabeth', 'Elsa & Fred', 'Elza', 'Ernest & Celestine', 'Evil Words', 'Evolution', 'Fly Me to the Moon', 'Forget Me Not', 'Grace of Monaco', 'Guess Who', 'Hells Angels', 'History of the World: Part I', 'Holy Motors', 'I Am Number Four', 'Incendies', 'Intolerable Cruelty', 'Irreversible', 'Jumper', 'Le Havre', 'Little Nicholas', 'Little White Lies', 'March of the Penguins', 'Master and Commander: The Far Side of the World', 'Micmacs', 'Mississippi Mermaid', 'Moliere', 'Monty Python and the Holy Grail', 'Moulin Rouge!', 'Mozarts Sister', 'Neal n Nikki', 'No Escape', 'Now You See Me', 'Oceans', 'Oceans Twelve', 'One to Another', 'Oscar and Lucinda', 'Pearl Harbor', 'Pierrot le Fou', 'Rise of the Guardians', 'Rushmore', 'See Spot Run', 'Shrek the Third', 'Silent Movie', 'Simply Irresistible', 'Slumdog Millionaire', 'Somethings Gotta Give', 'Spectre', 'Subway', 'The Artist', 'The Awakening', 'The Blue Room', 'The Bélier Family', 'The Case of the Grinning Cat', 'The Chorus', 'The Class', 'The Country Doctor', 'The Diving Bell and the Butterfly', 'The Flower of Evil', 'The Girl on the Train', 'The Green Mile', 'The Horseman on the Roof', 'The Incredibles', 'The Married Woman', 'The Names of Love', 'The Next Best Thing', 'The Others', 'The Painted Veil', 'The Princess and the Frog', 'The Statement', 'The Swindle', 'The Triplets of Belleville', 'The Visitors', 'The Visitors II: The Corridors of Time', 'The Walk', 'The Widow of Saint-Pierre', 'The Wolf of Wall Street', 'They Will Have to Kill Us First', 'Tinker Tailor Soldier Spy', 'Up Close & Personal', 'Wasabi', 'Welcome to the Sticks', 'What Just Happened', 'When the Cats Away', 'Wild Grass']
# Black and White Movies
# ['Creative Control', 'Frances Ha', 'Frankenweenie', 'Renaissance', 'The Giver', 'The Phantom of the Opera']
# Colored Movies
forbidden Kingdom', 'Forgetting Sarah Marshall', 'Frenzy', 'Frost/Nixon', 'Funny People', 'Furious 7', 'Georgia Rule', 'Get Him to the Greek', 'Gladiator', 'Green Zone', 'Hail, Caesar!', 'Half Baked', 'Halloween III: Season of the Witch', 'Happy Gilmore', 'Heartbeeps', 'Hellboy II: The Golden Army', 'High Plains Drifter', 'Honey', 'Hop', 'Hot Fuzz', 'House of 1000 Corpses', 'How High', 'How the Grinch Stole Christmas', 'Howard the Duck', 'Hulk', 'Inglourious Basterds', 'Inside Man', 'Intolerable Cruelty', 'Isnt She Great', 'Its Complicated', 'Jarhead', 'Jaws 2', 'Jaws', 'Jaws: The Revenge', 'Johnny English Reborn', 'Johnny English', 'Josie and the Pussycats', 'Jurassic Park', 'Kick-Ass 2', 'Kicking & Screaming', 'Kindergarten Cop', 'King Kong', 'Knocked Up', 'Krampus', 'Land of the Dead', 'Land of the Lost', 'Larry Crowne', 'Leap Year', 'Leatherheads', 'Legal Eagles', 'Les Misérables', 'Lets Go to Prison', 'Liar Liar', 'Little Fockers', 'Lone Survivor', 'Love Actually', 'Love Happens', 'Lucy', 'Mama', 'Mamma Mia!', 'Man of the Year', 'Master and Commander: The Far Side of the World', 'Meet Joe Black', 'Meet the Fockers', 'Meet the Parents', 'Mercury Rising', 'Midnight Run', 'Minions', 'Mo Better Blues', 'Munich', 'My Big Fat Greek Wedding 2', 'Mystery Men', 'Nanny McPhee and the Big Bang', 'Nanny McPhee', 'Neighbors 2: Sorority Rising', 'Neighbors', 'Nighthawks', 'Nutty Professor II: The Klumps', 'O Brother, Where Art Thou?', 'Oblivion', 'One True Thing', 'Ouija', 'Out of Africa', 'Out of Sight', 'Patch Adams', 'Paul', 'Phantasm II', 'Pitch Perfect 2', 'Pride & Prejudice', 'Primary Colors', 'Psycho', 'Public Enemies', 'R.I.P.D.', 'Raising Cain', 'Ray', 'Red Dragon', 'Repo Men', 'Ride Along 2', 'Ride Along', 'Ride with the Devil', 'Robin Hood', 'Role Models', 'Safe House', 'Sanctum', 'Scarface', 'Schindlers List', 'Scott Pilgrim vs. the World', 'Screwed', 'Seabiscuit', 'Serenity', 'Sgt. Bilko', 'Shakespeare in Love', 'Shaun of the Dead', 'Silent Running', 'Slither', 'Small Soldiers', 'Smokin Aces', 'Snow Falling on Cedars', 'Snow White and the Huntsman', 'Sorcerer', 'Southland Tales', 'Spotlight', 'Spy Game', 'State of Play', 'Steve Jobs', 'Straight Outta Compton', 'Street Fighter', 'Sweet Charity', 'Tales from the Crypt: Demon Knight', 'Ted 2', 'Ted' ...
# Common Production Country
 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb', 'Dragonslayer', 'Dreaming of Joseph Lees', 'Dredd', 'Driving Lessons', 'Dungeons & Dragons: Wrath of the Dragon God', 'East Is East', 'Eastern Promises', 'Easy Virtue', 'Eddie the Eagle', 'Eden Lake', 'Edge of Darkness', 'Elizabeth: The Golden Age', 'Ella Enchanted', 'Enemy at the Gates', 'Entrapment', 'Eragon', 'Eulogy', 'Event Horizon', 'Everest', 'Ex Machina', 'Exam', 'Exodus: Gods and Kings', 'Eye of the Beholder', 'Eyes Wide Shut', 'Fantastic 4: Rise of the Silver Surfer', 'Fascination', 'Fateless', 'FearDotCom', 'Felicias Journey', 'Fifty Dead Men Walking', 'Finding Neverland', 'Fish Tank', 'Flicka', 'Florence Foster Jenkins', 'Flushed Away', 'Flyboys', 'For Your Eyes Only', 'Force 10 from Navarone', 'Four Lions', 'Four Weddings and a Funeral', 'Freeze Frame', 'Frenzy', 'Fright Night', 'From Hell', 'From Paris with Love', 'From Russia with Love', 'Funny Games', 'Fury', 'Gandhi', 'Garfield: A Tail of Two Kitties', 'George and the Dragon', 'Ghost World', 'Girl with a Pearl Earring', 'Gladiator', 'Goal!: The Dream Begins', 'Gods and Monsters', 'GoldenEye', 'Goldfinger', 'Good Night, and Good Luck.', 'Good', 'Gosford Park', 'Grabbers', 'Gravity',  ...
# Movies released on the same decade as The Matrix
# 10 Things I Hate About You
# 20 Dates
# 200 Cigarettes
# 24 7: Twenty Four Seven
# 3 Ninjas Kick Back
# 54
# 8 Heads in a Duffel Bag
# 8MM
# A Bugs Life
# A Civil Action
# A Dog Of Flanders
# A Few Good Men
# A League of Their Own
# A Low Down Dirty Shame
# A Night at the Roxbury
# A Room for Romeo Brass
# A Simple Plan
# A Simple Wish
# A Thin Line Between Love and Hate
# A Time to Kill
# A Walk on the Moon
# Absolute Power
# Ace Ventura: Pet Detective
# Ace Ventura: When Nature Calls
# Aimee & Jaguar
# Air Bud
# Air Force One
# Airborne
# Aladdin
# Albino Alligator
# Alien: Resurrection
# Alien³
# Alive
# American Beauty
# American History X
# American Pie
# Amistad
# Among Giants
# An Alan Smithee Film: Burn, Hollywood, Burn
# An Ideal Husband
# Anaconda
# Analyze This
# Anastasia
# Angelas Ashes
# Anna and the King
# Antz
# Any Given Sunday
# Anywhere But Here
# Apollo 13
# Arachnophobia
# Arlington Road
# Armageddon
# Army of Darkness
# As Good as It Gets
# Assassins
# At First Sight
# Austin Powers: International Man of Mystery
# Austin Powers: The Spy Who Shagged Me
# Babe
# Babe: Pig in the City
# Baby Geniuses
# Babys Day Out
# Back to the Future Part III
# Bad Boys
# Bang
# Barneys Great Adventure
# Basquiat
# Batman & Robin
# Batman Forever
# Batman Returns
# Bats
# Beastmaster 2: Through the Portal of Time
# Beavis and Butt-Head Do America
# Before Sunrise
# Being John Malkovich
# Beloved
# Beverly Hills Cop III
# Beyond the Mat
# Bicentennial Man
# Big Daddy
# Bill & Teds Bogus Journey
# Blade
# Blast from the Past
# Blood and Wine
# Blue Streak
# Bogus
# Boogie Nights
# Boomerang
# Bottle Rocket
# Bound by Honor
# Bound
# Bowfinger
# Boys Dont Cry
# Boyz n the Hood
# Braveheart
# Breakdown
# Breakfast of Champions
# Bride of Chucky
# Bringing Out the Dead
# Brokedown Palace
# Ulees Gold
# Under Siege 2: Dark Territory
# Unforgiven
# Universal Soldier: The Return
# Up Close & Personal
# Urban Legend
# Vampire in Brooklyn
# Vampires
# Varsity Blues
# Velvet Goldmine
# Very Bad Things
# Virtuosity
# Volcano
# Wag the Dog
# Waiting for Guffman
# Waking Ned
# Walking and Talking
# Warlock: The Armageddon
# Warriors of Virtue
# Waterworld
# Waynes World
# Welcome to the Dollhouse
# What Dreams May Come
# Whats Eating Gilbert Grape
# Whats Love Got to Do with It
# When the Cats Away
# White Fang
# White Squall
# Wild Things
# Wild Wild West
# Wing Commander
# Without Limits
# Wolf
# Woo
# Wyatt Earp
# Youve Got Mail
# Zero Effect
# eXistenZ

# %% [markdown]
# # **2ο Μέρος: Recommendation System με βάση μόνο τα χαρακτηριστικά των ταινιών.**
#
# Στο σημείο αυτό με βάση τους κανόνες που κατασκευάστηκαν στο Μέρος 1 θα κατασκευαστούν κατηγορήματα για την ομοιότητα ταινιών. Παρακάτω δίνεται ένα μικρό παράδειγμα ενός κανόνα και πώς αυτός θα μπορούσε να γραφτεί μέσω του Pyswip. Επίσης όπως αναφέρεται και σε σχόλιο παραπάνω θα μπορεί να γραφτεί και μια βάση δεδομένων με τους κανόνες και να γίνει απευθείας consult.
#
# Στο παρακάτω παράδειγμα το 5 και το 4 εκφράζουν την ομοιότητα των ταινιών π.χ. οι ταινίες που παράγονται μέσω του find_similar_5 είναι πιο όμοιες από αυτές που παράγονται μέσω του find_similar_4.

# %%
prolog.assertz('both_black_and_white(Movie1,Movie2) :- (black_and_white(Movie1),black_and_white(Movie2))')

prolog.assertz('same_color(Movie1, Movie2) :- (both_black_and_white(Movie1,Movie2)) ; (color(Movie1),color(Movie2))')

prolog.assertz('same_language(Movie1, Movie2) :- language(Movie1,L), language(Movie2,L)')

prolog.assertz('same_country(Movie1, Movie2) :- country(Movie1,C), country(Movie2,C)')

prolog.assertz('same_studio(Movie1, Movie2) :- studio(Movie1,S), studio(Movie2,S)')

prolog.assertz('n_same_genre(Movie1, N, Movie2) :- movie(Movie1), movie(Movie2), Movie1 \= Movie2, setof(Genre, genre(Movie1, Genre), Genres1), setof(Genre, genre(Movie2, Genre), Genres2), intersection(Genres1, Genres2, CommonGenres), length(CommonGenres, Count), Count >= N')

prolog.assertz('n_same_keyword(Movie1, N, Movie2) :- movie(Movie1), movie(Movie2), Movie1 \= Movie2, setof(Keyword1, plot_keyword(Movie1, Keyword1), Keywords1), setof(Keyword2, plot_keyword(Movie2, Keyword2), Keywords2), intersection(Keywords1, Keywords2, CommonKeywords), length(CommonKeywords, Count), Count >= N')

prolog.assertz('n_same_actor(Movie1, N, Movie2) :- movie(Movie1), movie(Movie2), Movie1 \= Movie2, setof(A, (actor(Movie1, A), actor(Movie2, A)), Common_actors), length(Common_actors, Cnt), Cnt >= N')

prolog.assertz('same_director(Movie1, Movie2) :- director(Movie1,D), director(Movie2,D)')

prolog.assertz('same_year(Movie,Movie2) :- release_year(Movie1,Y), release_year(Movie2,Y)')


prolog.assertz('find_sim_1(Movie, Other) :- (n_same_genre(Movie, 1, Other), n_same_keyword(Movie,1,Other)) ; (same_year(Movie,Other))')
prolog.assertz('find_sim_2(Movie,Other) :- find_sim_1(Movie,Other),n_same_keyword(Movie,2,Other),n_same_genre(Movie, 2, Other)')
prolog.assertz('find_sim_3(Movie,Other) :- (find_sim_2(Movie,Other), n_same_keyword(Movie,3,Other),(black_and_white(Movie) -> both_black_and_white(Movie, Other) ; true)) ; same_director(Movie,Other)')
prolog.assertz('find_sim_4(Movie,Other) :- (find_sim_3(Movie, Other), (setof(G, genre(Movie, G), Genres), length(Genres, N), N >= 3 -> n_same_genre(Movie, 3, Other) ; true))')
prolog.assertz('find_sim_5(Movie,Other) :- (find_sim_4(Movie,Other), n_same_keyword(Movie, 4, Other)) ; (find_sim_2(Movie, Other), same_director(Movie,Other),same_studio(Movie,Other)) ; (find_sim_3(Movie, Other),(n_same_actor(Movie,3,Other)))')



def simple_recommender(movie):
    s = set()
    rec = []
    q = prolog.query("find_sim_5('" + movie +"',M)")
    for soln in q:
        m = soln['M']
        if m not in s:
            s.add(soln['M'])
            rec.append((m,5))
    q.close()

    q = prolog.query("find_sim_4('" + movie +"',M)")
    for soln in q:
        m = soln['M']
        if m not in s:
            s.add(soln['M'])
            rec.append((m,4))
    q.close()

    q = prolog.query("find_sim_3('" + movie +"',M)")
    for soln in q:
        m = soln['M']
        if m not in s:
            s.add(soln['M'])
            rec.append((m,3))
    q.close()

    q = prolog.query("find_sim_2('" + movie +"',M)")
    for soln in q:
        m = soln['M']
        if m not in s:
            s.add(soln['M'])
            rec.append((m,2))
    q.close()

    q = prolog.query("find_sim_1('" + movie +"',M)")
    for soln in q:
        m = soln['M']
        if m not in s:
            s.add(soln['M'])
            rec.append((m,1))
    q.close()

    answers = rec
    return answers


# def slight_match_recommender(movie):
#     s = set()
#     q = prolog.query("find_sim_2('" + movie +"',M)")
#     for soln in q:
#         m = soln['M']
#         if m not in s:
#             s.add(soln['M'])
#     q.close()
#     answers = s
#     return answers


# def average_match_recommender(movie):
#     s = set()
#     q = prolog.query("find_sim_3('" + movie +"',M)")
#     for soln in q:
#         m = soln['M']
#         if m not in s:
#             s.add(soln['M'])
#     q.close()
#     answers = s
#     return answers


# def good_match_recommender(movie):
#     s = set()
#     q = prolog.query("find_sim_4('" + movie +"',M)")
#     for soln in q:
#         m = soln['M']
#         if m not in s:
#             s.add(soln['M'])
#     q.close()
#     answers = s
#     return answers


# def perfect_match_recommender(movie):
#     s = set()
#     q = prolog.query("find_sim_5('" + movie +"',M)")
#     for soln in q:
#         m = soln['M']
#         if m not in s:
#             s.add(soln['M'])
#     q.close()
#     answers = s
#     return answers

# %%
# print("Recommendations: Avatar")
# print(list(simple_recommender('Inception'))[:5])

# %% [markdown]
# # **3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις-Αξιολογήσεις του χρήστη-Εκπαίδευση και Πρόβλεψη**
#
#
# Αρχικά μελετάμε τις αξιολογήσεις κάθε χρήστη για να καταλάβουμε την δομή και τις πληροφορίες κάθε αρχείου.

# %%
from tqdm.notebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import random
from sklearn.preprocessing import MinMaxScaler

rating_weights = {0: -1, 1: -0.5, 2:0, 3:0, 4:0.5, 5:1}
score_weights = {i:i + 1 for i in range(1,6)} # ανάλογα με τα επίπεδα ομοιότητας που έχουν οριστεί στην simple_recommender

def normalize_scores(scores):
    scaler = MinMaxScaler()
    movie_list = list(scores.items())
    names, values = zip(*movie_list)
    scaled = scaler.fit_transform(np.array(values).reshape(-1, 1)).flatten()
    return dict(zip(names, scaled))

def train_recommender(ratings, rating_weights, score_weights, number_of_movies = 10):
    """
    Στην συνάρτηση αυτή μπορούμε να ορίζουμε ποιο υποσύνολο των αξιολογήσεων θα χρησιμοποιήσουμε για το train μαζί με τα βάρη ομοιότητας και σκορ
    Σε συνδυασμό με τον αριθμό των ταινιών που θέλουμε να χρησιμοποιήσουμε σαν σύνολο δεδομένων π.χ. 10 από τις 100 ή 3 από τις 100 κ.ο.κ
    Αν θέλουμε να χρησιμοποιήσουμε όλες τις ταινίες σαν training set τότε ορίζουμε το number_of_movies = - 1
    """

    if number_of_movies > len(ratings):
        number_of_movies = len(ratings)


    if number_of_movies != -1:
        indexes = random.sample(range(len(ratings)), number_of_movies)
        ratings = ratings.iloc[indexes]

    movie_score = {}
    for row in tqdm(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        similar_movies = simple_recommender(movie)

        for similar_movie,level in similar_movies:
            if similar_movie not in movie_score:
                movie_score[similar_movie] = rating_weights[int(rating)] * score_weights[level]
            else:
                movie_score[similar_movie] += rating_weights[int(rating)] * score_weights[level] # το weight θα το ορίσετε ανα επίπεδο ομοιότητας οι πολύ όμοιες ταινίες θα έχουν μεγαλύτερο βάρος
    return movie_score





# Αυτό είναι ένα παράδειγμα για το πως θα μπορούσε να υλοποιήθει η predict.
# Έχουμε ορίσει ότι μια ταινία θα έπρεπε να είναι προτεινόμενη αν είχε σκορ > 0.
def predict_example(ratings, movie_score):
    real, pred = [], []
    for i, row in enumerate(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        if movie in movie_score: #αν έχουμε σχηματίσει βαθμολογία για την ταινία αυτή
            pred.append(int(movie_score[movie] > 0)) #heuristic για το αν μια ταινία είναι προτεινόμενη
            real.append(int(rating > 3))# έτσι ορίζουμε ότι μια ταινία θα έπρεπε να είναι προτεινόμενη
            #η συνθήκη αυτή δεν μπορεί να αλλάξει
        else: #δεν μπορούμε να προτείνουμε κάτι για το όποιο δεν έχουμε σχηματίσει εικόνα
            pred.append(0)
            real.append(int(rating > 2))

    return real, pred


def get_metrics(real, pred):
    metrics = {}
    metrics["precision"] = precision_score(real, pred)
    metrics["recall"] = recall_score(real, pred)
    metrics["f1"] = f1_score(real, pred)
    return metrics

# %% [markdown]
# Η παραπάνω εκπαιδεύουν, τεστάρουν και μετρούν την απόδοσή του συστήματος στάσεων μας. Για την εκπαίδευση του συστήματος μπορούμε κάθε φορά να χρησιμοποιήσουμε ένα τυχαίο υποσύνολο του training set. Όμως είναι πιθανό το υποσύνολο των ταινιών αυτόν να επηρεάζει τα αποτελέσματα στο training set. Για παράδειγμα από 3 ταινίες στις 10 μπορούν για ένα πείραμα τα αποτελέσματα μας αν είναι ίδια και αυτό να μην οφείλεται στο γεγονός ότι ο ταξινομητής μας τα πηγαίνει καλά στις 3 ταινίες αλλά στο γεγονός ότι οι υπόλοιπες 7 είναι τέτοιες ταινίες που δεν μας βοηθούν καθόλου και αν είχαμε επιλέξει διαφορετικές 3 ταινίες να τα πηγαίναμε χάλια. Οπότε προτείνουμε να τρέξετε κάθε φορά έναν αριθμό πειραμάτων για κάθε υποσύνολο ταινιών π.χ. 10 πειράματα με 3 ταινίες, 10 πειράματα για 20 ταινίες κ.ο.κ. και να κρατήσετε σαν τελικό σκορ το μέσο όρο όλων των πειραμάτων. Έτσι τα αποτελέσματα των αγγλικών σας θα είναι πιο αντικειμενικά.

# %%
train_ratings = pd.read_csv(path + "train_ratings.csv")
test_ratings = pd.read_csv(path + "test_ratings.csv")

# %%
metrics = []
for i in range (4):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 10)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5106382978723404
# recall: 1.0
# f1: 0.676056338028169

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, -1)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-c3d8b571da9e> in <cell line: 0>()
#       1 metrics = []
#       2 for i in range (10):
# ----> 3     movie_score = train_recommender(train_ratings, rating_weights, score_weights, -1)
#       4     real, pred = predict_example(test_ratings, movie_score)
#       5     metrics.append(get_metrics(real, pred))
#
# <ipython-input-10-4f9e126e4803> in train_recommender(ratings, rating_weights, score_weights, number_of_movies)
#      35         rating = getattr(row, 'rating')
#      36
# ---> 37         similar_movies = simple_recommender(movie)
#      38
#      39         for similar_movie,level in similar_movies:
#
# <ipython-input-8-4498d0cab21d> in simple_recommender(movie)
#      32     rec = []
#      33     q = prolog.query("find_sim_5('" + movie +"',M)")
# ---> 34     for soln in q:
#      35         m = soln['M']
#      36         if m not in s:
#
# /usr/local/lib/python3.11/dist-packages/pyswip/prolog.py in __call__(self, query, maxresult, catcherrors, normalize)
#     150             Prolog._queryIsOpen = True  # From now on, the query will be considered open
#     151             try:
# --> 152                 while maxresult and PL_next_solution(swipl_qid):
#     153                     maxresult -= 1
#     154                     swipl_list = PL_copy_term_ref(swipl_bindingList)
#
# KeyboardInterrupt:
